# %%
import pandas as pd
import matplotlib.pylab as plt

data = pd.read_csv('lfso_24eab01$defaultview_linear.csv')
data.sample()
# Out:
#                                  DATAFLOW        LAST UPDATE    freq      sex  \
# 2682  ESTAT:LFSO_24EAB01$DEFAULTVIEW(1.0)  15/12/25 11:00:00  Annual  Females
#
#                       age                isced11  \
# 2682  From 15 to 34 years  All ISCED 2011 levels
#
#                                        training     geo        unit  \
# 2682  No formal education or training abandoned  Greece  Percentage
#
#       TIME_PERIOD  OBS_VALUE OBS_FLAG  CONF_STATUS
# 2682         2024       98.5      NaN          NaN
